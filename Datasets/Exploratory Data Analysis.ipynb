# %% [markdown]
# # 10Alytics Data Analytics Hackathon

# %% [markdown]
# ### Olaniyan Oladimeji Mumini

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Abstract

# %% [markdown]
# The aim of this project is to find solutions to the health challenges, especially in Africa.

# %% [markdown]
# ## Data wrangling

# %%
# downloading the datasets by importing them using the pandas library
number_of_death_by_cause = pd.read_csv('annual_number_of_deaths_by_cause.csv')
number_of_death_by_age = pd.read_csv('number_of_deaths_by_age_group.csv')
number_of_medical_doctors = pd.read_csv('medical_doctors_per_10000.csv', encoding='ISO-8859-1')
world_population = pd.read_csv('world_population.csv')
health_expenditure = pd.read_csv('current_health_expenditure.csv')

# %%
number_of_death_by_cause.head(20)
# Out:
#         Country  Year  Meningitis  Alzheimer's disease and other dementias  \
# 0   Afghanistan  2007      2933.0                                   1402.0
# 1   Afghanistan  2008      2731.0                                   1424.0
# 2   Afghanistan  2009      2460.0                                   1449.0
# 3   Afghanistan  2011      2327.0                                   1508.0
# 4   Afghanistan  2012      2254.0                                   1544.0
# 5   Afghanistan  2013      2281.0                                   1581.0
# 6   Afghanistan  2014      1935.0                                   1620.0
# 7   Afghanistan  2015      1821.0                                   1652.0
# 8   Afghanistan  2016      1795.0                                   1690.0
# 9   Afghanistan  1990      2159.0                                   1116.0
# 10  Afghanistan  1991      2218.0                                   1136.0
# ...
